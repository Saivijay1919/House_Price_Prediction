# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

pd.pandas.set_option('display.max_columns',None)
pd.pandas.set_option('display.max_rows',None)

# %%
data = pd.read_csv(r'F:\ML\Datasets\HousePrice_pre.csv')

data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# # Finding Null values in the dataset

# %%
data.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.drop(columns=['Id','PoolQC','MiscFeature','Fence','Alley'],axis=1,inplace=True)

print('After removing 5 col',data.shape)
# Out:
# After removing 5 col (1460, 76)

# %% [markdown]
# # list of numerical variables

# %%
# list of numerical variables
numerical_features = [feature for feature in data.columns if data[feature].dtypes != 'O']

print('Number of numerical variables: ', len(numerical_features))

print(numerical_features)

# visualise the numerical variables
data[numerical_features].head()
# Out:
# Number of numerical variables:  37
# ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# ...

# %% [markdown]
# # Replacing the null values with there mean valuerespectively

# %%
# replacing the null values with there mean valuerespectively

for features in numerical_features:
    meanValue = data[features].mean()
    #data[features+'nan']=np.where(data[features].isnull(),1,0)
    data[features].fillna(meanValue, inplace=True)

# %%
# cross verifing / checking

data[numerical_features].isnull().sum()
# Out:
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea       0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %% [markdown]
# # Finding Categorical Features

# %%
cate_fea= [features for features in data.columns if data[features].isnull().sum() >1 and data[features].dtype =='O']

for features in cate_fea:
    print("{} : {} this many values mised".format(features, data[features].isnull().sum()))
# Out:
# MasVnrType : 8 this many values mised
# BsmtQual : 37 this many values mised
# BsmtCond : 37 this many values mised
# BsmtExposure : 38 this many values mised
# BsmtFinType1 : 37 this many values mised
# BsmtFinType2 : 38 this many values mised
# FireplaceQu : 690 this many values mised
# GarageType : 81 this many values mised
# GarageFinish : 81 this many values mised
# GarageQual : 81 this many values mised
# GarageCond : 81 this many values mised

# %%
data.shape
# Out:
# (1460, 76)

# %%
## Replace missing value with a new label
def replace_cat_feature(data,cate_fea):
    data[cate_fea]=data[cate_fea].fillna('Missing')
    return data

data=replace_cat_feature(data,cate_fea)

data[cate_fea].isnull().sum()
# Out:
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# dtype: int64

# %%
# list of variables that contain year information
year_feature = [feature for feature in numerical_features if 'Yr' in feature or 'Year' in feature]

year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
# let's explore the content of these year variables
for feature in year_feature:
    print(feature, data[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
## Temporal Variables (Date Time Variables)

for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
       
    data[feature]=data['YrSold']-data[feature]

# %%
data[['YearBuilt','YearRemodAdd','GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %%
#perform log normal distribution

import numpy as np
num_features=['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']

for feature in num_features:
    data[feature]=np.log(data[feature])

# %%
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage   LotArea Street LotShape LandContour  \
# 0          60       RL     4.174387  9.041922   Pave      Reg         Lvl
# 1          20       RL     4.382027  9.169518   Pave      Reg         Lvl
# 2          60       RL     4.219508  9.328123   Pave      IR1         Lvl
# 3          70       RL     4.094345  9.164296   Pave      IR1         Lvl
# 4          60       RL     4.430817  9.565214   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
categorical_features=[feature for feature in data.columns if data[feature].dtype=='O']

# %%
print(categorical_features)
# Out:
# ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']

# %%
for feature in categorical_features:
    temp=data.groupby(feature)['SalePrice'].count()/len(data)
    temp_df=temp[temp>0.01].index
    data[feature]=np.where(data[feature].isin(temp_df),data[feature],'Rare_var')

# %%
data.head(2)
# Out:
#    MSSubClass MSZoning  LotFrontage   LotArea Street LotShape LandContour  \
# 0          60       RL     4.174387  9.041922   Pave      Reg         Lvl
# 1          20       RL     4.382027  9.169518   Pave      Reg         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl     Rare_var      Feedr       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     2Story            7            5          5             5     Gable
# 1     1Story            6            8         31            31     Gable
#
#   RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# 0  CompShg     VinylSd     VinylSd    BrkFace       196.0        Gd        TA
# 1  CompShg     MetalSd     MetalSd       None         0.0        TA        TA
#
# ...

# %% [markdown]
# # Converting the categorical features into numerical

# %%
for feature in categorical_features:
    labels_ordered=data.groupby([feature])['SalePrice'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    data[feature]=data[feature].map(labels_ordered)

# %%
data.shape
# Out:
# (1460, 76)

# %%
data.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  LandContour  \
# 0          60         3     4.174387  9.041922       1         0            1
# 1          20         3     4.382027  9.169518       1         0            1
# 2          60         3     4.219508  9.328123       1         1            1
# 3          70         3     4.094345  9.164296       1         1            1
# 4          60         3     4.430817  9.565214       1         1            1
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0          1          0          0            14           2           1
# 1          1          2          0            11           1           1
# 2          1          0          0            14           2           1
# 3          1          1          0            16           2           1
# 4          1          2          0            22           2           1
#
# ...

# %%
data.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
# ...

# %%
data.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  LandContour  \
# 0          60         3     4.174387  9.041922       1         0            1
# 1          20         3     4.382027  9.169518       1         0            1
# 2          60         3     4.219508  9.328123       1         1            1
# 3          70         3     4.094345  9.164296       1         1            1
# 4          60         3     4.430817  9.565214       1         1            1
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0          1          0          0            14           2           1
# 1          1          2          0            11           1           1
# 2          1          0          0            14           2           1
# 3          1          1          0            16           2           1
# 4          1          2          0            22           2           1
#
# ...

# %% [markdown]
# # Applying MINMAX Scaling

# %%
feature_scale=[feature for feature in data.columns if feature not in ['SalePrice']]

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(data[feature_scale])
# Out:
# MinMaxScaler()

# %%
scaler.transform(data[feature_scale])
# Out:
# array([[0.23529412, 0.75      , 0.41820812, ..., 0.5       , 0.66666667,
#         0.75      ],
#        [0.        , 0.75      , 0.49506375, ..., 0.25      , 0.66666667,
#         0.75      ],
#        [0.23529412, 0.75      , 0.434909  , ..., 0.5       , 0.66666667,
#         0.75      ],
#        ...,
#        [0.29411765, 0.75      , 0.42385922, ..., 1.        , 0.66666667,
#         0.75      ],
#        [0.        , 0.75      , 0.434909  , ..., 1.        , 0.66666667,
#         0.75      ],
#        [0.        , 0.75      , 0.47117546, ..., 0.5       , 0.66666667,
#         0.75      ]])

# %%
data.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  LandContour  \
# 0          60         3     4.174387  9.041922       1         0            1
# 1          20         3     4.382027  9.169518       1         0            1
# 2          60         3     4.219508  9.328123       1         1            1
# 3          70         3     4.094345  9.164296       1         1            1
# 4          60         3     4.430817  9.565214       1         1            1
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0          1          0          0            14           2           1
# 1          1          2          0            11           1           1
# 2          1          0          0            14           2           1
# 3          1          1          0            16           2           1
# 4          1          2          0            22           2           1
#
# ...

# %%
# transform the train and test set, and add on the Id and SalePrice variables
da = pd.concat([data[['SalePrice']].reset_index(drop=True),
                    pd.DataFrame(scaler.transform(data[feature_scale]), columns=feature_scale)],
                    axis=1)

# %%
da.head()
# Out:
#    SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  \
# 0  12.247694    0.235294      0.75     0.418208  0.366344     1.0  0.000000
# 1  12.109011    0.000000      0.75     0.495064  0.391317     1.0  0.000000
# 2  12.317167    0.235294      0.75     0.434909  0.422359     1.0  0.333333
# 3  11.849398    0.294118      0.75     0.388581  0.390295     1.0  0.333333
# 4  12.429216    0.235294      0.75     0.513123  0.468761     1.0  0.333333
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0     0.333333        1.0       0.00        0.0      0.636364         0.4
# 1     0.333333        1.0       0.50        0.0      0.500000         0.2
# 2     0.333333        1.0       0.00        0.0      0.636364         0.4
# 3     0.333333        1.0       0.25        0.0      0.727273         0.4
# 4     0.333333        1.0       0.50        0.0      1.000000         0.4
#
# ...

# %%
da.corr()
# Out:
#                SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  \
# SalePrice       1.000000   -0.073959  0.410575     0.346178  0.399918
# MSSubClass     -0.073959    1.000000 -0.211535    -0.477121 -0.462668
# MSZoning        0.410575   -0.211535  1.000000     0.316911  0.321035
# LotFrontage     0.346178   -0.477121  0.316911     1.000000  0.655013
# LotArea         0.399918   -0.462668  0.321035     0.655013  1.000000
# Street          0.057369   -0.024969  0.084606    -0.034230 -0.105723
# LotShape        0.281623   -0.103700  0.187166     0.141243  0.351985
# LandContour     0.154134   -0.027856  0.045657     0.041437  0.135558
# Utilities       0.012632    0.022844 -0.009400    -0.003906 -0.023403
# LotConfig       0.145078   -0.053177  0.095729     0.018858  0.230379
# LandSlope       0.038526   -0.025672  0.006208     0.061922  0.255881
# Neighborhood    0.739974   -0.024106  0.553530     0.236596  0.245556
# ...

# %%
da.isnull().sum()
# Out:
# SalePrice        0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# ...

# %%
da.isnull().sum().sum()
# Out:
# 0

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
X=da.iloc[:,1:]
y=da.iloc[:,0]

# %%
X.isnull().sum().sum()
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
X_train.shape
# Out:
# (1022, 75)

# %%
X_test.shape
# Out:
# (438, 75)

# %% [markdown]
# # Finding Feature Importance

# %%
### Feature Importance

from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %% [markdown]
# # finding top 16 important features

# %%
#plot graph of feature importances for better visualization

#finding top 16 important features***********

feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(16).plot(kind='barh')
plt.show()

# %% [markdown]
# # Saving the data into an excel file

# %%
da.to_csv('HPP_Use_this_PP.csv',index=False)

# %% [markdown]
# # Applying LazyRegressor to apply all models at a time

# %%
# import necessary modules
import warnings
warnings.filterwarnings('ignore')
import time 
from sklearn.datasets import load_iris,fetch_california_housing
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyClassifier,LazyRegressor

# %%
regmodel=LazyRegressor(verbose=0,predictions=True)

# %%
# fit and train the model 
start_time_1=time.time()
models_c,predictions_c=regmodel.fit(X_train, X_test, y_train, y_test)
end_time_1=time.time()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:19<00:00,  2.18it/s]

# %%
# to check which model did better on the UNSW-NB15 dataset 
models_c
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                    0.88       0.90  0.12        0.80
# HistGradientBoostingRegressor                0.88       0.90  0.13        4.98
# RandomForestRegressor                        0.87       0.89  0.13        2.39
# ExtraTreesRegressor                          0.87       0.89  0.13        2.01
# LGBMRegressor                                0.87       0.89  0.13        0.44
# XGBRegressor                                 0.85       0.88  0.14        0.56
# LassoLarsCV                                  0.84       0.87  0.14        0.22
# ElasticNetCV                                 0.84       0.87  0.14        0.23
# LassoCV                                      0.84       0.87  0.14        0.22
# LassoLarsIC                                  0.84       0.87  0.14        0.06
# BaggingRegressor                             0.84       0.87  0.14        0.26
# ...

# %%
# to check the predications for the models 
predictions_c
# Out:
#      AdaBoostRegressor  BaggingRegressor  BayesianRidge  \
# 0                12.30             12.39          12.21
# 1                11.90             11.80          11.90
# 2                11.52             11.56          11.66
# 3                12.36             12.33          12.31
# 4                11.46             11.43          11.42
# 5                11.37             11.51          11.39
# 6                12.34             12.52          12.47
# 7                11.83             11.52          11.75
# 8                12.91             13.32          13.35
# 9                12.00             11.89          12.01
# 10               12.15             12.18          12.20
# 11               11.91             11.96          11.78
# 12               12.32             12.32          12.34
# 13               11.73             11.62          11.72
# 14               11.75             11.75          11.72
# 15               11.79             11.82          11.83
# ...
